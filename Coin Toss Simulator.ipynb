# %%
# imports
import numpy as np
import matplotlib.pyplot as plt

# %%
# variable declaration
dice_lower_limit = 1
dice_upper_limit = 6
number_of_dice = 10

# %%
# simulating the dice rolls
def rollDice(lower_limit, upper_limit, no_dice):
    return np.random.randint(lower_limit, upper_limit+1, no_dice, dtype=np.int8)

# %%
# function to claculate average
def rollsAverage(rolls):
    avg = np.mean(rolls)
    avg = round(avg, 3)
    return avg

# %%
# function to calculate probability
def rollsProb(rolls):
    prob = dict()
    for i in range(dice_lower_limit, dice_upper_limit):
        p = float(np.count_nonzero(i == rolls) / len(rolls))
        prob[i] = p
    return prob

# %%
# plotting distribution function
def rollsPlot(rolls):
    plt.hist(rolls, bins=np.arange(dice_lower_limit, dice_upper_limit+2)-0.5, edgecolor="black")
    plt.xticks(range(dice_lower_limit, dice_upper_limit+1))
    plt.title('Frequency Distribution (Histogram)')
    plt.xlabel('Value')
    plt.ylabel('Frequency')
    plt.grid(axis='y', alpha=0.75)
    plt.show()

# %% [markdown]
# **Rolling 10 Dice**

# %%
rolls = rollDice(dice_lower_limit, dice_upper_limit, number_of_dice)
print(f"Average {rollsAverage(rolls)}")
print(f"Probability: {rollsProb(rolls)}")
print("Distribution: ")
rollsPlot(rolls)
# Out:
# Average 3.469
# Probability: {1: 0.15, 2: 0.197, 3: 0.159, 4: 0.18, 5: 0.156}
# Distribution:

# %% [markdown]
# **Rolling 100 Dice**

# %%
number_of_dice = 100
rolls = rollDice(dice_lower_limit, dice_upper_limit, number_of_dice)
print(f"Average {rollsAverage(rolls)}")
print(f"Probability: {rollsProb(rolls)}")
print("Distribution: ")
rollsPlot(rolls)
# Out:
# Average 3.45
# Probability: {1: 0.18, 2: 0.19, 3: 0.12, 4: 0.2, 5: 0.13}
# Distribution:

# %% [markdown]
# **Rolling 1000 Dice**

# %%
number_of_dice = 1000
rolls = rollDice(dice_lower_limit, dice_upper_limit, number_of_dice)
print(f"Average {rollsAverage(rolls)}")
print(f"Probability: {rollsProb(rolls)}")
print("Distribution: ")
rollsPlot(rolls)
# Out:
# Average 3.476
# Probability: {1: 0.181, 2: 0.157, 3: 0.158, 4: 0.178, 5: 0.161}
# Distribution:

# %% [markdown]
# **Rolling 10,000 dice**

# %%
number_of_dice = 10_000
rolls = rollDice(dice_lower_limit, dice_upper_limit, number_of_dice)
print(f"Average {rollsAverage(rolls)}")
print(f"Probability: {rollsProb(rolls)}")
print("Distribution: ")
rollsPlot(rolls)
# Out:
# Average 3.488
# Probability: {1: 0.1682, 2: 0.1682, 3: 0.1659, 4: 0.1656, 5: 0.1696}
# Distribution:

# %% [markdown]
# **Rolling 100,000 Dice**

# %%
number_of_dice = 100_000
rolls = rollDice(dice_lower_limit, dice_upper_limit, number_of_dice)
print(f"Average {rollsAverage(rolls)}")
print(f"Probability: {rollsProb(rolls)}")
print("Distribution: ")
rollsPlot(rolls)
# Out:
# Average 3.507
# Probability: {1: 0.16685, 2: 0.16355, 3: 0.16777, 4: 0.16695, 5: 0.16732}
# Distribution:

# %% [markdown]
# **Rolling 1,000,000 Dice**

# %%
number_of_dice = 1_000_000
rolls = rollDice(dice_lower_limit, dice_upper_limit, number_of_dice)
print(f"Average {rollsAverage(rolls)}")
print(f"Probability: {rollsProb(rolls)}")
print("Distribution: ")
rollsPlot(rolls)
# Out:
# Average 3.5
# Probability: {1: 0.166244, 2: 0.166588, 3: 0.167025, 4: 0.167208, 5: 0.16665}
# Distribution:

# %% [markdown]
# **Rolling 10,000,000 Dice**

# %%
number_of_dice = 10_000_000
rolls = rollDice(dice_lower_limit, dice_upper_limit, number_of_dice)
print(f"Average {rollsAverage(rolls)}")
print(f"Probability: {rollsProb(rolls)}")
print("Distribution: ")
rollsPlot(rolls)
# Out:
# Average 3.5
# Probability: {1: 0.1665909, 2: 0.1666103, 3: 0.1666832, 4: 0.1668159, 5: 0.1666485}
# Distribution:

# %% [markdown]
# **Rolling 100,000,000 Dice**

# %%
number_of_dice = 100_000_000
rolls = rollDice(dice_lower_limit, dice_upper_limit, number_of_dice)
print(f"Average {rollsAverage(rolls)}")
print(f"Probability: {rollsProb(rolls)}")
print("Distribution: ")
rollsPlot(rolls)
# Out:
# Average 3.5
# Probability: {1: 0.16666797, 2: 0.16670575, 3: 0.16660623, 4: 0.16664938, 5: 0.16672117}
# Distribution:
